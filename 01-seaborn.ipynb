# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.set_theme() # adiciona tema padrao, para aplicar em todos os graficos

# %%
df = pd.read_csv("data-visualization-graficos-bibliotecas-python\imigrantes_canada.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\forti\AppData\Local\Temp\ipykernel_13712\224779405.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv("data-visualization-graficos-bibliotecas-python\imigrantes_canada.csv")

# %%
top_10 = df.sort_values(by="Total", ascending=False).head(10)

# %%
sns.barplot(x="Total", y="País", data=top_10, orient="h")
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y="País", x="Total", orient="h", palette="vlag")
ax.set(title="Imigrantes para o Canada  \n 1980 a 2013", xlabel="Nr. de imigrantes", ylabel="")

plt.show()
# Out:
# C:\Users\forti\AppData\Local\Temp\ipykernel_13712\4083086798.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y="País", x="Total", orient="h", palette="vlag")

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax = sns.barplot(data=top_10, y="País", x="Total", orient="h")

ax.set_title("Paises com maior imigracao para o Canada\n1980 a 2013", loc="left", fontsize=16)
ax.set_xlabel("Nr. de imigrantes", fontsize=12)
ax.set_ylabel("")

plt.show()

# %%
def gerar_grafico_paleta(palette, legend=True):
    fig, ax = plt.subplots(figsize=(8, 4))
    ax = sns.barplot(data=top_10, y="País", x="Total", orient="h", palette=palette, hue="País", legend=legend)

    ax.set_title("Paises com maior imigracao para o Canada\n1980 a 2013", loc="left", fontsize=16)
    ax.set_xlabel("Nr. de imigrantes", fontsize=12)
    ax.set_ylabel("")

    plt.show()

# %%
gerar_grafico_paleta("Blues_r")

# %%
gerar_grafico_paleta("rocket", legend=False)

# %%
gerar_grafico_paleta("tab10", legend=False)

# %%
sns.set_theme(style="dark")
gerar_grafico_paleta("tab10", legend=False)

# %%
sns.set_theme(style="whitegrid")
gerar_grafico_paleta("tab10", legend=False)

# %%
sns.set_theme(style="white")
gerar_grafico_paleta("tab10", legend=False)

# %%
sns.set_theme(style="ticks")
gerar_grafico_paleta("tab10", legend=False)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax = sns.barplot(data=top_10, y="País", x="Total", orient="h", palette="tab10", hue="País")

ax.set_title("Paises com maior imigracao para o Canada\n1980 a 2013", loc="left", fontsize=16)
ax.set_xlabel("Nr. de imigrantes", fontsize=12)
ax.set_ylabel("")
sns.despine() # remove as caixas superiores..

plt.show()

# %%
df.set_index("País", inplace=True)

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
_df = df.copy()

# %%
colunas = df.loc[:,"1980":"2013"].columns
_df = _df.melt(id_vars=["País", "Continente", "Região"], value_vars=colunas, value_name="imigrantes", var_name="anos")
_df.set_index("País", inplace=True)

# %%
_df.loc['Brasil', :]
# Out:
#                        Continente          Região  anos  imigrantes
# País
# Brasil  América Latina e o Caribe  América do Sul  1980         211
# Brasil  América Latina e o Caribe  América do Sul  1981         220
# Brasil  América Latina e o Caribe  América do Sul  1982         192
# Brasil  América Latina e o Caribe  América do Sul  1983         139
# Brasil  América Latina e o Caribe  América do Sul  1984         145
# Brasil  América Latina e o Caribe  América do Sul  1985         130
# Brasil  América Latina e o Caribe  América do Sul  1986         205
# Brasil  América Latina e o Caribe  América do Sul  1987         244
# Brasil  América Latina e o Caribe  América do Sul  1988         394
# Brasil  América Latina e o Caribe  América do Sul  1989         650
# Brasil  América Latina e o Caribe  América do Sul  1990         650
# Brasil  América Latina e o Caribe  América do Sul  1991         877
# Brasil  América Latina e o Caribe  América do Sul  1992        1066
# ...

# %%
_df.loc['Brasil'].anos.values
# Out:
# array(['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013'], dtype=object)

# %%
sns.set_theme()
sns.set_palette('Dark2')

fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(x="anos", y="imigrantes", data=_df.loc["Brasil"], label='Brasil', lw=3)
ax = sns.lineplot(x="anos", y="imigrantes", data=_df.loc["Argentina"], label='Argentina', lw=3)
ax = sns.lineplot(x="anos", y="imigrantes", data=_df.loc["Peru"], label='Peru', lw=3)
ax = sns.lineplot(x="anos", y="imigrantes", data=_df.loc["Colômbia"], label='Colômbia', lw=3)

ax.set_title('Imigração dos maiores países da América do Sul\npara o Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))

plt.show()
